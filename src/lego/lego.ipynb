# %%
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time

# %%
from IPython import display

# %%
dataset_path = ".\dataset\images"

# %%
im = PIL.Image.open(f"{dataset_path}\\0001.jpg")
im.show()

# %%
latent_dim = 100
img_size = (512, 512)
epochs = 100
batch_size = 16

# %%
def load_images(dataset_path):
    images = []
    for filename in os.listdir(dataset_path):
        img = Image.open(os.path.join(dataset_path, filename))
        img = img.resize(img_size)
        img = np.array(img) / 255.0
        images.append(img)
    return images

all_images = load_images(dataset_path=dataset_path)

plt.imshow(all_images[0], interpolation='nearest')
plt.show()
